# %%
# !pip3 install pymysql
# !pip install flask flask-cors

# %%
#Libraries for dataframe and connection with database
import pandas as pd
import numpy as np
import pymysql
#Building of API using flask
from flask import Flask,jsonify
import json
from werkzeug.wrappers import Request, Response
import os
from flask_cors import CORS, cross_origin

# %%
result = pd.DataFrame()
resultAllYear = pd.DataFrame()
result16 = pd.DataFrame()
result17 = pd.DataFrame()
result18 = pd.DataFrame()
result19 = pd.DataFrame()
result20 = pd.DataFrame()
result21 = pd.DataFrame()
result22 = pd.DataFrame()
dateDataframe=pd.DataFrame()

# %%
#Database Connection
conn=pymysql.connect(host='10.121.44.72' ,port=int(3306),user='root',passwd='abcd@1234',db='helnis')
database_data=pd.read_sql_query("SELECT * FROM test3 ",conn)
# Out:
# C:\Users\faaiz.asif\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
#Dropping empty values and setting date formata
database_data.dropna(axis=0, inplace=True)
database_data['Date'] = pd.to_datetime(database_data['Date'], errors='coerce', format='%Y-%m-%d')
database_data.head()
# Out:
#         Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  GoldRate  \
# 0 2022-06-17      0.982608  0.869135   0.156542  1.000000  0.581416  0.971955
# 1 2022-06-16      0.988147  0.952868   0.140187  0.997605  0.565407  1.000000
# 2 2022-06-15      0.989624  0.929093   0.142056  0.980841  0.554046  0.981609
# 3 2022-06-14      0.988147  0.966840   0.140654  0.973656  0.539070  0.959299
# 4 2022-06-13      0.987408  0.987696   0.141589  0.952103  0.532256  0.955619
#
#    ArifHabib  AskariBank  EngroPowergen  InterestGoogle  CrudeOilGoogle  \
# 0   0.527195    0.319407       0.200283            47.0            53.0
# 1   0.534792    0.302561       0.164384            48.0             9.0
# 2   0.534792    0.332210       0.171941            65.0             9.0
# 3   0.532260    0.332210       0.169580            44.0            25.0
# 4   0.532260    0.292453       0.165328            25.0            43.0
#
#    PSXGoogle  USDPKRGoogle  KSEGoogle  GoldGoogle
# ...

# %%
database_data['InterestRate'] = database_data['InterestRate'].round(decimals=3)
database_data['CrudeOil'] = database_data['CrudeOil'].round(decimals=3)
database_data['PSXEquity'] = database_data['PSXEquity'].round(decimals=3)
database_data['USDToPKR'] = database_data['USDToPKR'].round(decimals=3)
database_data['KSEPrice'] = database_data['KSEPrice'].round(decimals=3)
database_data['GoldRate'] = database_data['GoldRate'].round(decimals=3)
database_data['ArifHabib']= database_data['ArifHabib'].round(decimals=3)
database_data['AskariBank'] = database_data['AskariBank'].round(decimals=3)
database_data['EngroPowergen'] = database_data['EngroPowergen'].round(decimals=3)

# %%
#Making data dataframe to integrate later
dateDataframe['Date']=database_data['Date']
dateDataframe.head()
# Out:
#         Date
# 0 2022-06-17
# 1 2022-06-16
# 2 2022-06-15
# 3 2022-06-14
# 4 2022-06-13

# %%
database_data.drop('Date',axis=1, inplace=True)
database_data.head()
# Out:
#    InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  GoldRate  ArifHabib  \
# 0         0.983     0.869      0.157     1.000     0.581     0.972      0.527
# 1         0.988     0.953      0.140     0.998     0.565     1.000      0.535
# 2         0.990     0.929      0.142     0.981     0.554     0.982      0.535
# 3         0.988     0.967      0.141     0.974     0.539     0.959      0.532
# 4         0.987     0.988      0.142     0.952     0.532     0.956      0.532
#
#    AskariBank  EngroPowergen  InterestGoogle  CrudeOilGoogle  PSXGoogle  \
# 0       0.319          0.200            47.0            53.0       35.0
# 1       0.303          0.164            48.0             9.0       32.0
# 2       0.332          0.172            65.0             9.0       40.0
# 3       0.332          0.170            44.0            25.0       49.0
# 4       0.292          0.165            25.0            43.0       51.0
#
#    USDPKRGoogle  KSEGoogle  GoldGoogle
# ...

# %%
frames=[dateDataframe,database_data]
database_data=pd.concat(frames,axis=1)
database_data.head()
# Out:
#         Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  GoldRate  \
# 0 2022-06-17         0.983     0.869      0.157     1.000     0.581     0.972
# 1 2022-06-16         0.988     0.953      0.140     0.998     0.565     1.000
# 2 2022-06-15         0.990     0.929      0.142     0.981     0.554     0.982
# 3 2022-06-14         0.988     0.967      0.141     0.974     0.539     0.959
# 4 2022-06-13         0.987     0.988      0.142     0.952     0.532     0.956
#
#    ArifHabib  AskariBank  EngroPowergen  InterestGoogle  CrudeOilGoogle  \
# 0      0.527       0.319          0.200            47.0            53.0
# 1      0.535       0.303          0.164            48.0             9.0
# 2      0.535       0.332          0.172            65.0             9.0
# 3      0.532       0.332          0.170            44.0            25.0
# 4      0.532       0.292          0.165            25.0            43.0
#
#    PSXGoogle  USDPKRGoogle  KSEGoogle  GoldGoogle
# ...

# %%
result=database_data.copy()
result['Date'] = pd.to_datetime(result['Date'], errors='coerce', format='%Y-%m-%d')
result.head()
# Out:
#         Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  GoldRate  \
# 0 2022-06-17         0.983     0.869      0.157     1.000     0.581     0.972
# 1 2022-06-16         0.988     0.953      0.140     0.998     0.565     1.000
# 2 2022-06-15         0.990     0.929      0.142     0.981     0.554     0.982
# 3 2022-06-14         0.988     0.967      0.141     0.974     0.539     0.959
# 4 2022-06-13         0.987     0.988      0.142     0.952     0.532     0.956
#
#    ArifHabib  AskariBank  EngroPowergen  InterestGoogle  CrudeOilGoogle  \
# 0      0.527       0.319          0.200            47.0            53.0
# 1      0.535       0.303          0.164            48.0             9.0
# 2      0.535       0.332          0.172            65.0             9.0
# 3      0.532       0.332          0.170            44.0            25.0
# 4      0.532       0.292          0.165            25.0            43.0
#
#    PSXGoogle  USDPKRGoogle  KSEGoogle  GoldGoogle
# ...

# %%
resultAllYear['InterestRate'] = result.groupby([result['Date'].dt.year]).agg({'InterestRate': ['mean']})
resultAllYear['CrudeOil'] = result.groupby([result['Date'].dt.year]).agg({'CrudeOil': ['mean']})
resultAllYear['PSXEquity'] = result.groupby([result['Date'].dt.year]).agg({'PSXEquity': ['mean']})
resultAllYear['USDTOPKR'] = result.groupby([result['Date'].dt.year]).agg({'USDToPKR': ['mean']})
resultAllYear['KSEPrice'] = result.groupby([result['Date'].dt.year]).agg({'KSEPrice': ['mean']})
resultAllYear['GoldRate'] = result.groupby([result['Date'].dt.year]).agg({'GoldRate': ['mean']})
resultAllYear['ArifHabib'] = result.groupby([result['Date'].dt.year]).agg({'ArifHabib': ['mean']})
resultAllYear['AskariBank'] = result.groupby([result['Date'].dt.year]).agg({'AskariBank': ['mean']})
resultAllYear['EngroPowergen'] = result.groupby([result['Date'].dt.year]).agg({'EngroPowergen': ['mean']})
resultAllYear['InterestGoogle'] = result.groupby([result['Date'].dt.year]).agg({'InterestGoogle': ['mean']}).apply(np.ceil)
resultAllYear['CrudeOilGoogle'] = result.groupby([result['Date'].dt.year]).agg({'CrudeOilGoogle': ['mean']}).apply(np.ceil)
resultAllYear['PSXGoogle'] = result.groupby([result['Date'].dt.year]).agg({'PSXGoogle': ['mean']}).apply(np.ceil)
resultAllYear['USDPKRGoogle'] = result.groupby([result['Date'].dt.year]).agg({'USDPKRGoogle': ['mean']}).apply(np.ceil)
resultAllYear['KSEGoogle'] = result.groupby([result['Date'].dt.year]).agg({'KSEGoogle': ['mean']}).apply(np.ceil)
resultAllYear['GoldGoogle'] = result.groupby([result['Date'].dt.year]).agg({'GoldGoogle': ['mean']}).apply(np.ceil)
resultAllYear.reset_index(inplace=True)

# %%
resultAllYear['Date'] = resultAllYear['Date'].astype(int)
resultAllYear['InterestRate'] = resultAllYear['InterestRate'].round(decimals=3)
resultAllYear['CrudeOil'] = resultAllYear['CrudeOil'].round(decimals=3)
resultAllYear['PSXEquity'] = resultAllYear['PSXEquity'].round(decimals=3)
resultAllYear['KSEPrice'] = resultAllYear['KSEPrice'].round(decimals=3)
resultAllYear['GoldRate'] = resultAllYear['GoldRate'].round(decimals=3)
resultAllYear['ArifHabib']= resultAllYear['ArifHabib'].round(decimals=3)
resultAllYear['AskariBank'] = resultAllYear['AskariBank'].round(decimals=3)
resultAllYear['EngroPowergen'] = resultAllYear['EngroPowergen'].round(decimals=3)

resultAllYear.head()
# Out:
#    Date  InterestRate  CrudeOil  PSXEquity  USDTOPKR  KSEPrice  GoldRate  \
# 0  2016         0.022     0.186      0.433  0.007302     0.407     0.186
# 1  2017         0.016     0.274      0.533  0.011777     0.715     0.196
# 2  2018         0.176     0.301      0.651  0.169221     0.582     0.259
# 3  2019         0.715     0.278      0.282  0.439744     0.346     0.438
# 4  2020         0.340     0.186      0.247  0.548887     0.433     0.686
#
#    ArifHabib  AskariBank  EngroPowergen  InterestGoogle  CrudeOilGoogle  \
# 0      0.703       0.509          0.696            36.0            36.0
# 1      0.649       0.514          0.821            41.0            28.0
# 2      0.440       0.659          0.756            42.0            26.0
# 3      0.182       0.443          0.354            35.0            20.0
# 4      0.426       0.305          0.212            41.0            17.0
#
#    PSXGoogle  USDPKRGoogle  KSEGoogle  GoldGoogle
# ...

# %%
#Yearly from 2016-2022 for graph purpose
dictionaryYearlyagg = resultAllYear.to_dict('records')
dictionaryYearlyagg
# Out:
# [{'Date': 2016,
#   'InterestRate': 0.022,
#   'CrudeOil': 0.186,
#   'PSXEquity': 0.433,
#   'USDTOPKR': 0.00730241935483871,
#   'KSEPrice': 0.407,
#   'GoldRate': 0.186,
#   'ArifHabib': 0.703,
#   'AskariBank': 0.509,
#   'EngroPowergen': 0.696,
#   'InterestGoogle': 36.0,
#   'CrudeOilGoogle': 36.0,
#   'PSXGoogle': 0.0,
#   'USDPKRGoogle': 54.0,
#   'KSEGoogle': 40.0,
#   'GoldGoogle': 56.0},
#  {'Date': 2017,
#   'InterestRate': 0.016,
#   'CrudeOil': 0.274,
#   'PSXEquity': 0.533,
#   'USDTOPKR': 0.01177732793522267,
#   'KSEPrice': 0.715,
#   'GoldRate': 0.196,
#   'ArifHabib': 0.649,
#   'AskariBank': 0.514,
#   'EngroPowergen': 0.821,
#   'InterestGoogle': 41.0,
#   'CrudeOilGoogle': 28.0,
#   'PSXGoogle': 28.0,
#   'USDPKRGoogle': 55.0,
#   'KSEGoogle': 38.0,
#   'GoldGoogle': 60.0},
#  {'Date': 2018,
#   'InterestRate': 0.176,
#   'CrudeOil': 0.301,
#   'PSXEquity': 0.651,
#   'USDTOPKR': 0.16922131147540984,
#   'KSEPrice': 0.582,
#   'GoldRate': 0.259,
# ...

# %%
dataframeAllYears=pd.DataFrame()
dataframeAllYears=database_data.copy()
dataframeAllYears['Date'] = dataframeAllYears['Date'].astype(str)
dataframeAllYears.head()
# Out:
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2022-06-17         0.983     0.869      0.157     1.000     0.581
# 1  2022-06-16         0.988     0.953      0.140     0.998     0.565
# 2  2022-06-15         0.990     0.929      0.142     0.981     0.554
# 3  2022-06-14         0.988     0.967      0.141     0.974     0.539
# 4  2022-06-13         0.987     0.988      0.142     0.952     0.532
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# 0     0.972      0.527       0.319          0.200            47.0
# 1     1.000      0.535       0.303          0.164            48.0
# 2     0.982      0.535       0.332          0.172            65.0
# 3     0.959      0.532       0.332          0.170            44.0
# 4     0.956      0.532       0.292          0.165            25.0
#
#    CrudeOilGoogle  PSXGoogle  USDPKRGoogle  KSEGoogle  GoldGoogle
# 0            53.0       35.0          37.0       20.0        53.0
# ...

# %%
#Transforming dataframe into Dictionary
dictionary = dataframeAllYears.to_dict('records')
dictionary
# Out:
# [{'Date': '2022-06-17',
#   'InterestRate': 0.983,
#   'CrudeOil': 0.869,
#   'PSXEquity': 0.157,
#   'USDToPKR': 1.0,
#   'KSEPrice': 0.581,
#   'GoldRate': 0.972,
#   'ArifHabib': 0.527,
#   'AskariBank': 0.319,
#   'EngroPowergen': 0.2,
#   'InterestGoogle': 47.0,
#   'CrudeOilGoogle': 53.0,
#   'PSXGoogle': 35.0,
#   'USDPKRGoogle': 37.0,
#   'KSEGoogle': 20.0,
#   'GoldGoogle': 53.0},
#  {'Date': '2022-06-16',
#   'InterestRate': 0.988,
#   'CrudeOil': 0.953,
#   'PSXEquity': 0.14,
#   'USDToPKR': 0.998,
#   'KSEPrice': 0.565,
#   'GoldRate': 1.0,
#   'ArifHabib': 0.535,
#   'AskariBank': 0.303,
#   'EngroPowergen': 0.164,
#   'InterestGoogle': 48.0,
#   'CrudeOilGoogle': 9.0,
#   'PSXGoogle': 32.0,
#   'USDPKRGoogle': 34.0,
#   'KSEGoogle': 36.0,
#   'GoldGoogle': 51.0},
#  {'Date': '2022-06-15',
#   'InterestRate': 0.99,
#   'CrudeOil': 0.929,
#   'PSXEquity': 0.142,
#   'USDToPKR': 0.981,
#   'KSEPrice': 0.554,
#   'GoldRate': 0.982,
#   'ArifHabib': 0.535,
# ...

# %%
dataframeAllYears.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of All the Years
list0=[]
list0=dataframeAllYears.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list0['index1']=list0.index
print(list0)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil        0.411601       1
# 2    InterestRate       PSXEquity       -0.576108       2
# 3    InterestRate        USDToPKR        0.670598       3
# 4    InterestRate        KSEPrice       -0.309165       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle        0.089909     220
# 221    GoldGoogle       PSXGoogle        0.018778     221
# 222    GoldGoogle    USDPKRGoogle        0.444635     222
# 223    GoldGoogle       KSEGoogle        0.070232     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation = list0.to_dict('index')
dictionary_relation
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': 0.4116009568566861,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.5761083116390934,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.6705982573992281,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.30916517726474974,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': 0.48602175608837456,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': -0.6585466394417435,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': -0.24386594479851278,
#   'index1': 7},
# ...

# %%
dataframeTwentyTwo = pd.DataFrame()
dataframeTwentyOne = pd.DataFrame()
dataframeTwenty = pd.DataFrame()
dataframeNineteen = pd.DataFrame()
dataframeEighteen = pd.DataFrame()
dataframeSeventeen = pd.DataFrame()
dataframeSixteen = pd.DataFrame()

# %%
#Working on 2022 Dataset
dataframeTwentyTwo = database_data.loc[(database_data['Date'] >= '2022-01-01')
                     & (database_data['Date'] <= '2022-06-17')]
dataframeTwentyTwo['Date'] = dataframeTwentyTwo['Date'].astype(str)
dataframeTwentyTwo.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\3796419973.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeTwentyTwo['Date'] = dataframeTwentyTwo['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2022-06-17         0.983     0.869      0.157     1.000     0.581
# 1  2022-06-16         0.988     0.953      0.140     0.998     0.565
# 2  2022-06-15         0.990     0.929      0.142     0.981     0.554
# 3  2022-06-14         0.988     0.967      0.141     0.974     0.539
# 4  2022-06-13         0.987     0.988      0.142     0.952     0.532
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary22 = dataframeTwentyTwo.to_dict('records')
dictionary22
# Out:
# [{'Date': '2022-06-17',
#   'InterestRate': 0.983,
#   'CrudeOil': 0.869,
#   'PSXEquity': 0.157,
#   'USDToPKR': 1.0,
#   'KSEPrice': 0.581,
#   'GoldRate': 0.972,
#   'ArifHabib': 0.527,
#   'AskariBank': 0.319,
#   'EngroPowergen': 0.2,
#   'InterestGoogle': 47.0,
#   'CrudeOilGoogle': 53.0,
#   'PSXGoogle': 35.0,
#   'USDPKRGoogle': 37.0,
#   'KSEGoogle': 20.0,
#   'GoldGoogle': 53.0},
#  {'Date': '2022-06-16',
#   'InterestRate': 0.988,
#   'CrudeOil': 0.953,
#   'PSXEquity': 0.14,
#   'USDToPKR': 0.998,
#   'KSEPrice': 0.565,
#   'GoldRate': 1.0,
#   'ArifHabib': 0.535,
#   'AskariBank': 0.303,
#   'EngroPowergen': 0.164,
#   'InterestGoogle': 48.0,
#   'CrudeOilGoogle': 9.0,
#   'PSXGoogle': 32.0,
#   'USDPKRGoogle': 34.0,
#   'KSEGoogle': 36.0,
#   'GoldGoogle': 51.0},
#  {'Date': '2022-06-15',
#   'InterestRate': 0.99,
#   'CrudeOil': 0.929,
#   'PSXEquity': 0.142,
#   'USDToPKR': 0.981,
#   'KSEPrice': 0.554,
#   'GoldRate': 0.982,
#   'ArifHabib': 0.535,
# ...

# %%
#Monthly 2022
monthlyTwentyTwo=pd.DataFrame()
dataframeTwentyTwo['Date'] = pd.to_datetime(dataframeTwentyTwo['Date'], errors='coerce')
monthlyTwentyTwo['InterestRate']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlyTwentyTwo['CrudeOil']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlyTwentyTwo['PSXEquity']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlyTwentyTwo['USDToPKR']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlyTwentyTwo['KSEPrice']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlyTwentyTwo['GoldRate']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlyTwentyTwo['ArifHabib']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlyTwentyTwo['AskariBank']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlyTwentyTwo['EngroPowergen']=dataframeTwentyTwo.groupby([dataframeTwentyTwo['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlyTwentyTwo['InterestRate'] = monthlyTwentyTwo['InterestRate'].round(decimals=3)
monthlyTwentyTwo['CrudeOil'] = monthlyTwentyTwo['CrudeOil'].round(decimals=3)
monthlyTwentyTwo['PSXEquity'] = monthlyTwentyTwo['PSXEquity'].round(decimals=3)
monthlyTwentyTwo['KSEPrice'] = monthlyTwentyTwo['KSEPrice'].round(decimals=3)
monthlyTwentyTwo['GoldRate'] = monthlyTwentyTwo['GoldRate'].round(decimals=3)
monthlyTwentyTwo['ArifHabib']= monthlyTwentyTwo['ArifHabib'].round(decimals=3)
monthlyTwentyTwo['AskariBank'] = monthlyTwentyTwo['AskariBank'].round(decimals=3)
monthlyTwentyTwo['EngroPowergen'] = monthlyTwentyTwo['EngroPowergen'].round(decimals=3)

dictionaryMonthly2022 = monthlyTwentyTwo.to_dict('records')
dictionaryMonthly2022
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\2893532836.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeTwentyTwo['Date'] = pd.to_datetime(dataframeTwentyTwo['Date'], errors='coerce')
# [{'InterestRate': 0.516,
#   'CrudeOil': 0.557,
#   'PSXEquity': 0.32,
#   'USDToPKR': 0.6906,
#   'KSEPrice': 0.706,
#   'GoldRate': 0.793,
#   'ArifHabib': 0.284,
#   'AskariBank': 0.668,
#   'EngroPowergen': 0.173},
#  {'InterestRate': 0.498,
#   'CrudeOil': 0.624,
#   'PSXEquity': 0.289,
#   'USDToPKR': 0.6837,
#   'KSEPrice': 0.712,
#   'GoldRate': 0.81,
#   'ArifHabib': 0.446,
#   'AskariBank': 0.589,
#   'EngroPowergen': 0.399},
#  {'InterestRate': 0.585,
#   'CrudeOil': 0.768,
#   'PSXEquity': 0.242,
# ...

# %%
dataframeTwentyTwo.drop('Date', inplace=True, axis=1)
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\3935220681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeTwentyTwo.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2022
list1=[]
list1=dataframeTwentyTwo.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list1['index1']=list1.index
print(list1)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil        0.859099       1
# 2    InterestRate       PSXEquity       -0.818899       2
# 3    InterestRate        USDToPKR        0.926309       3
# 4    InterestRate        KSEPrice       -0.660648       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle        0.424624     220
# 221    GoldGoogle       PSXGoogle        0.317064     221
# 222    GoldGoogle    USDPKRGoogle        0.309700     222
# 223    GoldGoogle       KSEGoogle        0.245232     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation_2022 = list1.to_dict('index')
dictionary_relation_2022
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': 0.8590985929059354,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.8188993000061358,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.9263090223214294,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.6606478886094187,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': 0.8288525978576174,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': 0.047411263272348,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': -0.7061976520839223,
#   'index1': 7},
#  8: {'Factor1': 'InterestRate',
# ...

# %%
#Working on 2021 Dataset
dataframeTwentyOne = database_data.loc[(database_data['Date'] >= '2021-01-01')
                     & (database_data['Date'] <= '2021-12-31')]
dataframeTwentyOne['Date'] = dataframeTwentyOne['Date'].astype(str)
dataframeTwentyOne = dataframeTwentyOne.reset_index(drop=True)
dataframeTwentyOne.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\3857136696.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeTwentyOne['Date'] = dataframeTwentyOne['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2021-12-31         0.527     0.486      0.317     0.687     0.677
# 1  2021-12-30         0.527     0.502      0.322     0.707     0.670
# 2  2021-12-29         0.510     0.498      0.316     0.709     0.664
# 3  2021-12-28         0.504     0.492      0.310     0.711     0.656
# 4  2021-12-27         0.500     0.487      0.329     0.708     0.651
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary21 = dataframeTwentyOne.to_dict('records')
dictionary21
# Out:
# [{'Date': '2021-12-31',
#   'InterestRate': 0.527,
#   'CrudeOil': 0.486,
#   'PSXEquity': 0.317,
#   'USDToPKR': 0.687,
#   'KSEPrice': 0.677,
#   'GoldRate': 0.809,
#   'ArifHabib': 0.521,
#   'AskariBank': 0.623,
#   'EngroPowergen': 0.122,
#   'InterestGoogle': 52.0,
#   'CrudeOilGoogle': 8.0,
#   'PSXGoogle': 68.0,
#   'USDPKRGoogle': 74.0,
#   'KSEGoogle': 78.0,
#   'GoldGoogle': 43.0},
#  {'Date': '2021-12-30',
#   'InterestRate': 0.527,
#   'CrudeOil': 0.502,
#   'PSXEquity': 0.322,
#   'USDToPKR': 0.707,
#   'KSEPrice': 0.67,
#   'GoldRate': 0.803,
#   'ArifHabib': 0.512,
#   'AskariBank': 0.602,
#   'EngroPowergen': 0.126,
#   'InterestGoogle': 17.0,
#   'CrudeOilGoogle': 0.0,
#   'PSXGoogle': 82.0,
#   'USDPKRGoogle': 83.0,
#   'KSEGoogle': 64.0,
#   'GoldGoogle': 53.0},
#  {'Date': '2021-12-29',
#   'InterestRate': 0.51,
#   'CrudeOil': 0.498,
#   'PSXEquity': 0.316,
#   'USDToPKR': 0.709,
#   'KSEPrice': 0.664,
#   'GoldRate': 0.796,
#   'ArifHabib': 0.497,
# ...

# %%
#Monthly 2021
monthlyTwentyOne=pd.DataFrame()
dataframeTwentyOne['Date'] = pd.to_datetime(dataframeTwentyOne['Date'], errors='coerce')
monthlyTwentyOne['InterestRate']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlyTwentyOne['CrudeOil']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlyTwentyOne['PSXEquity']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlyTwentyOne['USDToPKR']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlyTwentyOne['KSEPrice']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlyTwentyOne['GoldRate']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlyTwentyOne['ArifHabib']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlyTwentyOne['AskariBank']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlyTwentyOne['EngroPowergen']=dataframeTwentyOne.groupby([dataframeTwentyOne['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlyTwentyOne['InterestRate'] = monthlyTwentyOne['InterestRate'].round(decimals=3)
monthlyTwentyOne['CrudeOil'] = monthlyTwentyOne['CrudeOil'].round(decimals=3)
monthlyTwentyOne['PSXEquity'] = monthlyTwentyOne['PSXEquity'].round(decimals=3)
monthlyTwentyOne['KSEPrice'] = monthlyTwentyOne['KSEPrice'].round(decimals=3)
monthlyTwentyOne['GoldRate'] = monthlyTwentyOne['GoldRate'].round(decimals=3)
monthlyTwentyOne['ArifHabib']= monthlyTwentyOne['ArifHabib'].round(decimals=3)
monthlyTwentyOne['AskariBank'] = monthlyTwentyOne['AskariBank'].round(decimals=3)
monthlyTwentyOne['EngroPowergen'] = monthlyTwentyOne['EngroPowergen'].round(decimals=3)



dictionaryMonthly2021 = monthlyTwentyOne.to_dict('records')
dictionaryMonthly2021
# Out:
# [{'InterestRate': 0.148,
#   'CrudeOil': 0.234,
#   'PSXEquity': 0.4,
#   'USDToPKR': 0.5361,
#   'KSEPrice': 0.723,
#   'GoldRate': 0.725,
#   'ArifHabib': 0.642,
#   'AskariBank': 0.71,
#   'EngroPowergen': 0.243},
#  {'InterestRate': 0.157,
#   'CrudeOil': 0.282,
#   'PSXEquity': 0.399,
#   'USDToPKR': 0.5261052631578947,
#   'KSEPrice': 0.744,
#   'GoldRate': 0.688,
#   'ArifHabib': 0.671,
#   'AskariBank': 0.749,
#   'EngroPowergen': 0.257},
#  {'InterestRate': 0.173,
#   'CrudeOil': 0.313,
#   'PSXEquity': 0.328,
#   'USDToPKR': 0.49559090909090914,
#   'KSEPrice': 0.691,
#   'GoldRate': 0.628,
#   'ArifHabib': 0.533,
#   'AskariBank': 0.606,
#   'EngroPowergen': 0.259},
#  {'InterestRate': 0.171,
#   'CrudeOil': 0.334,
#   'PSXEquity': 0.306,
#   'USDToPKR': 0.4661904761904762,
#   'KSEPrice': 0.687,
#   'GoldRate': 0.63,
#   'ArifHabib': 0.531,
#   'AskariBank': 0.428,
#   'EngroPowergen': 0.182},
#  {'InterestRate': 0.167,
#   'CrudeOil': 0.358,
#   'PSXEquity': 0.42,
# ...

# %%
dataframeTwentyOne.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2021
list2=[]
list2=dataframeTwentyOne.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list2['index1']=list2.index
print(list2)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil        0.507330       1
# 2    InterestRate       PSXEquity       -0.400369       2
# 3    InterestRate        USDToPKR        0.763593       3
# 4    InterestRate        KSEPrice       -0.533889       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle        0.013861     220
# 221    GoldGoogle       PSXGoogle        0.163994     221
# 222    GoldGoogle    USDPKRGoogle        0.471380     222
# 223    GoldGoogle       KSEGoogle        0.180801     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation_2021 = list2.to_dict('index')
dictionary_relation_2021
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': 0.5073299404014331,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.400369325522376,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.7635933478868525,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.5338888846704862,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': 0.6433113098036962,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': -0.45202182384546874,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': 0.1409584562018454,
#   'index1': 7},
#  8: {'Factor1': 'InterestRate',
# ...

# %%
#Working on 2020 Dataset
dataframeTwenty = database_data.loc[(database_data['Date'] >= '2020-01-01')
                     & (database_data['Date'] <= '2020-12-31')]
dataframeTwenty['Date'] = dataframeTwenty['Date'].astype(str)
dataframeTwenty = dataframeTwenty.reset_index(drop=True)
dataframeTwenty.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\301046731.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeTwenty['Date'] = dataframeTwenty['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2020-12-31         0.147     0.213      0.367     0.533     0.644
# 1  2020-12-30         0.147     0.214      0.392     0.535     0.642
# 2  2020-12-29         0.147     0.213      0.357     0.535     0.625
# 3  2020-12-28         0.146     0.211      0.357     0.538     0.641
# 4  2020-12-24         0.147     0.215      0.353     0.532     0.631
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary20 = dataframeTwenty.to_dict('records')
dictionary20
# Out:
# [{'Date': '2020-12-31',
#   'InterestRate': 0.147,
#   'CrudeOil': 0.213,
#   'PSXEquity': 0.367,
#   'USDToPKR': 0.533,
#   'KSEPrice': 0.644,
#   'GoldRate': 0.737,
#   'ArifHabib': 0.65,
#   'AskariBank': 0.644,
#   'EngroPowergen': 0.241,
#   'InterestGoogle': 31.0,
#   'CrudeOilGoogle': 0.0,
#   'PSXGoogle': 52.0,
#   'USDPKRGoogle': 59.0,
#   'KSEGoogle': 34.0,
#   'GoldGoogle': 36.0},
#  {'Date': '2020-12-30',
#   'InterestRate': 0.147,
#   'CrudeOil': 0.214,
#   'PSXEquity': 0.392,
#   'USDToPKR': 0.535,
#   'KSEPrice': 0.642,
#   'GoldRate': 0.736,
#   'ArifHabib': 0.649,
#   'AskariBank': 0.669,
#   'EngroPowergen': 0.257,
#   'InterestGoogle': 53.0,
#   'CrudeOilGoogle': 28.0,
#   'PSXGoogle': 80.0,
#   'USDPKRGoogle': 59.0,
#   'KSEGoogle': 56.0,
#   'GoldGoogle': 30.0},
#  {'Date': '2020-12-29',
#   'InterestRate': 0.147,
#   'CrudeOil': 0.213,
#   'PSXEquity': 0.357,
#   'USDToPKR': 0.535,
#   'KSEPrice': 0.625,
#   'GoldRate': 0.732,
#   'ArifHabib': 0.634,
# ...

# %%
#Monthly 2020
monthlyTwenty=pd.DataFrame()
dataframeTwenty['Date'] = pd.to_datetime(dataframeTwenty['Date'], errors='coerce')
monthlyTwenty['InterestRate']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlyTwenty['CrudeOil']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlyTwenty['PSXEquity']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlyTwenty['USDToPKR']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlyTwenty['KSEPrice']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlyTwenty['GoldRate']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlyTwenty['ArifHabib']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlyTwenty['AskariBank']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlyTwenty['EngroPowergen']=dataframeTwenty.groupby([dataframeTwenty['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlyTwenty['InterestRate'] = monthlyTwenty['InterestRate'].round(decimals=3)
monthlyTwenty['CrudeOil'] = monthlyTwenty['CrudeOil'].round(decimals=3)
monthlyTwenty['PSXEquity'] = monthlyTwenty['PSXEquity'].round(decimals=3)
monthlyTwenty['KSEPrice'] = monthlyTwenty['KSEPrice'].round(decimals=3)
monthlyTwenty['GoldRate'] = monthlyTwenty['GoldRate'].round(decimals=3)
monthlyTwenty['ArifHabib']= monthlyTwenty['ArifHabib'].round(decimals=3)
monthlyTwenty['AskariBank'] = monthlyTwenty['AskariBank'].round(decimals=3)
monthlyTwenty['EngroPowergen'] = monthlyTwenty['EngroPowergen'].round(decimals=3)




dictionaryMonthly2020 = monthlyTwenty.to_dict('records')
dictionaryMonthly2020
# Out:
# [{'InterestRate': 0.832,
#   'CrudeOil': 0.264,
#   'PSXEquity': 0.294,
#   'USDToPKR': 0.47981818181818175,
#   'KSEPrice': 0.594,
#   'GoldRate': 0.539,
#   'ArifHabib': 0.432,
#   'AskariBank': 0.501,
#   'EngroPowergen': 0.418},
#  {'InterestRate': 0.832,
#   'CrudeOil': 0.254,
#   'PSXEquity': 0.192,
#   'USDToPKR': 0.47563157894736835,
#   'KSEPrice': 0.491,
#   'GoldRate': 0.556,
#   'ArifHabib': 0.292,
#   'AskariBank': 0.42,
#   'EngroPowergen': 0.253},
#  {'InterestRate': 0.717,
#   'CrudeOil': 0.163,
#   'PSXEquity': 0.107,
#   'USDToPKR': 0.5213333333333333,
#   'KSEPrice': 0.248,
#   'GoldRate': 0.573,
#   'ArifHabib': 0.145,
#   'AskariBank': 0.133,
#   'EngroPowergen': 0.14},
#  {'InterestRate': 0.428,
#   'CrudeOil': 0.13,
#   'PSXEquity': 0.098,
#   'USDToPKR': 0.573047619047619,
#   'KSEPrice': 0.182,
#   'GoldRate': 0.655,
#   'ArifHabib': 0.217,
#   'AskariBank': 0.075,
#   'EngroPowergen': 0.121},
#  {'InterestRate': 0.251,
#   'CrudeOil': 0.119,
# ...

# %%
dataframeTwenty.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2020
list3=[]
list3=dataframeTwenty.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list3['index1']=list3.index
print(list3)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil        0.395813       1
# 2    InterestRate       PSXEquity       -0.373062       2
# 3    InterestRate        USDToPKR       -0.713432       3
# 4    InterestRate        KSEPrice       -0.080746       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle        0.292283     220
# 221    GoldGoogle       PSXGoogle        0.309541     221
# 222    GoldGoogle    USDPKRGoogle        0.439873     222
# 223    GoldGoogle       KSEGoogle        0.284800     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation_2020 = list3.to_dict('index')
dictionary_relation_2020
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': 0.3958134138295258,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.3730623166892505,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': -0.7134323906293092,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.08074626190149387,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': -0.8901582632478796,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': -0.45891065846866813,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': 0.03325273034063184,
#   'index1': 7},
# ...

# %%
#Working on 2019 Dataset
dataframeNineteen = database_data.loc[(database_data['Date'] >= '2019-01-01')
                     & (database_data['Date'] <= '2019-12-31')]
dataframeNineteen['Date'] = dataframeNineteen['Date'].astype(str)
dataframeNineteen = dataframeNineteen.reset_index(drop=True)
dataframeNineteen.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\4177379200.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeNineteen['Date'] = dataframeNineteen['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2019-12-31         0.835     0.269      0.258     0.483     0.527
# 1  2019-12-30         0.834     0.274      0.258     0.484     0.533
# 2  2019-12-27         0.833     0.274      0.249     0.481     0.531
# 3  2019-12-26         0.833     0.271      0.265     0.478     0.542
# 4  2019-12-24         0.832     0.271      0.251     0.477     0.511
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary19 = dataframeNineteen.to_dict('records')
dictionary19
# Out:
# [{'Date': '2019-12-31',
#   'InterestRate': 0.835,
#   'CrudeOil': 0.269,
#   'PSXEquity': 0.258,
#   'USDToPKR': 0.483,
#   'KSEPrice': 0.527,
#   'GoldRate': 0.52,
#   'ArifHabib': 0.451,
#   'AskariBank': 0.394,
#   'EngroPowergen': 0.496,
#   'InterestGoogle': 24.0,
#   'CrudeOilGoogle': 3.0,
#   'PSXGoogle': 69.0,
#   'USDPKRGoogle': 33.0,
#   'KSEGoogle': 59.0,
#   'GoldGoogle': 15.0},
#  {'Date': '2019-12-30',
#   'InterestRate': 0.834,
#   'CrudeOil': 0.274,
#   'PSXEquity': 0.258,
#   'USDToPKR': 0.484,
#   'KSEPrice': 0.533,
#   'GoldRate': 0.518,
#   'ArifHabib': 0.406,
#   'AskariBank': 0.366,
#   'EngroPowergen': 0.464,
#   'InterestGoogle': 16.0,
#   'CrudeOilGoogle': 0.0,
#   'PSXGoogle': 66.0,
#   'USDPKRGoogle': 37.0,
#   'KSEGoogle': 33.0,
#   'GoldGoogle': 19.0},
#  {'Date': '2019-12-27',
#   'InterestRate': 0.833,
#   'CrudeOil': 0.274,
#   'PSXEquity': 0.249,
#   'USDToPKR': 0.481,
#   'KSEPrice': 0.531,
#   'GoldRate': 0.516,
#   'ArifHabib': 0.433,
# ...

# %%
#Monthly 2019
monthlyNineteen=pd.DataFrame()
dataframeNineteen['Date'] = pd.to_datetime(dataframeNineteen['Date'], errors='coerce')
monthlyNineteen['InterestRate']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlyNineteen['CrudeOil']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlyNineteen['PSXEquity']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlyNineteen['USDToPKR']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlyNineteen['KSEPrice']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlyNineteen['GoldRate']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlyNineteen['ArifHabib']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlyNineteen['AskariBank']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlyNineteen['EngroPowergen']=dataframeNineteen.groupby([dataframeNineteen['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlyNineteen['InterestRate'] = monthlyNineteen['InterestRate'].round(decimals=3)
monthlyNineteen['CrudeOil'] = monthlyNineteen['CrudeOil'].round(decimals=3)
monthlyNineteen['PSXEquity'] = monthlyNineteen['PSXEquity'].round(decimals=3)
monthlyNineteen['KSEPrice'] = monthlyNineteen['KSEPrice'].round(decimals=3)
monthlyNineteen['GoldRate'] = monthlyNineteen['GoldRate'].round(decimals=3)
monthlyNineteen['ArifHabib']= monthlyNineteen['ArifHabib'].round(decimals=3)
monthlyNineteen['AskariBank'] = monthlyNineteen['AskariBank'].round(decimals=3)
monthlyNineteen['EngroPowergen'] = monthlyNineteen['EngroPowergen'].round(decimals=3)

dictionaryMonthly2019 = monthlyNineteen.to_dict('records')
dictionaryMonthly2019
# Out:
# [{'InterestRate': 0.5,
#   'CrudeOil': 0.286,
#   'PSXEquity': 0.361,
#   'USDToPKR': 0.34231818181818185,
#   'KSEPrice': 0.475,
#   'GoldRate': 0.344,
#   'ArifHabib': 0.322,
#   'AskariBank': 0.72,
#   'EngroPowergen': 0.593},
#  {'InterestRate': 0.521,
#   'CrudeOil': 0.293,
#   'PSXEquity': 0.351,
#   'USDToPKR': 0.340421052631579,
#   'KSEPrice': 0.51,
#   'GoldRate': 0.354,
#   'ArifHabib': 0.336,
#   'AskariBank': 0.613,
#   'EngroPowergen': 0.545},
#  {'InterestRate': 0.529,
#   'CrudeOil': 0.298,
#   'PSXEquity': 0.451,
#   'USDToPKR': 0.3440952380952381,
#   'KSEPrice': 0.454,
#   'GoldRate': 0.349,
#   'ArifHabib': 0.221,
#   'AskariBank': 0.476,
#   'EngroPowergen': 0.5},
#  {'InterestRate': 0.566,
#   'CrudeOil': 0.304,
#   'PSXEquity': 0.405,
#   'USDToPKR': 0.3565,
#   'KSEPrice': 0.387,
#   'GoldRate': 0.349,
#   'ArifHabib': 0.097,
#   'AskariBank': 0.471,
#   'EngroPowergen': 0.387},
#  {'InterestRate': 0.663,
#   'CrudeOil': 0.289,
#   'PSXEquity': 0.409,
# ...

# %%
dataframeNineteen.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2019
list4=[]
list4=dataframeNineteen.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list4['index1']=list4.index
print(list4)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil       -0.701891       1
# 2    InterestRate       PSXEquity       -0.766702       2
# 3    InterestRate        USDToPKR        0.963515       3
# 4    InterestRate        KSEPrice       -0.606847       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle        0.017427     220
# 221    GoldGoogle       PSXGoogle       -0.099785     221
# 222    GoldGoogle    USDPKRGoogle        0.485625     222
# 223    GoldGoogle       KSEGoogle        0.059396     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation_2019 = list4.to_dict('index')
dictionary_relation_2019
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': -0.7018909717396965,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.7667024583485759,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.9635146545323151,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.6068465261954659,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': 0.9590693734203856,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': -0.29437717276302844,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': -0.8229682418321903,
#   'index1': 7},
# ...

# %%
#Working on 2018 Dataset
dataframeEighteen = database_data.loc[(database_data['Date'] >= '2018-01-01')
                     & (database_data['Date'] <= '2018-12-31')]
dataframeEighteen['Date'] = dataframeEighteen['Date'].astype(str)
dataframeEighteen = dataframeEighteen.reset_index(drop=True)
dataframeEighteen.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\2427464717.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeEighteen['Date'] = dataframeEighteen['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2018-12-31         0.511     0.262      0.309     0.342     0.384
# 1  2018-12-28         0.510     0.251      0.307     0.343     0.387
# 2  2018-12-27         0.509     0.253      0.316     0.342     0.414
# 3  2018-12-26         0.507     0.270      0.332     0.342     0.428
# 4  2018-12-24         0.506     0.242      0.341     0.343     0.432
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary18 = dataframeEighteen.to_dict('records')
dictionary18
# Out:
# [{'Date': '2018-12-31',
#   'InterestRate': 0.511,
#   'CrudeOil': 0.262,
#   'PSXEquity': 0.309,
#   'USDToPKR': 0.342,
#   'KSEPrice': 0.384,
#   'GoldRate': 0.339,
#   'ArifHabib': 0.408,
#   'AskariBank': 0.727,
#   'EngroPowergen': 0.573,
#   'InterestGoogle': 0.0,
#   'CrudeOilGoogle': 0.0,
#   'PSXGoogle': 65.0,
#   'USDPKRGoogle': 9.0,
#   'KSEGoogle': 28.0,
#   'GoldGoogle': 72.0},
#  {'Date': '2018-12-28',
#   'InterestRate': 0.51,
#   'CrudeOil': 0.251,
#   'PSXEquity': 0.307,
#   'USDToPKR': 0.343,
#   'KSEPrice': 0.387,
#   'GoldRate': 0.336,
#   'ArifHabib': 0.373,
#   'AskariBank': 0.729,
#   'EngroPowergen': 0.573,
#   'InterestGoogle': 59.0,
#   'CrudeOilGoogle': 22.0,
#   'PSXGoogle': 54.0,
#   'USDPKRGoogle': 7.0,
#   'KSEGoogle': 57.0,
#   'GoldGoogle': 76.0},
#  {'Date': '2018-12-27',
#   'InterestRate': 0.509,
#   'CrudeOil': 0.253,
#   'PSXEquity': 0.316,
#   'USDToPKR': 0.342,
#   'KSEPrice': 0.414,
#   'GoldRate': 0.333,
#   'ArifHabib': 0.381,
# ...

# %%
#Monthly 2018
monthlyEighteen=pd.DataFrame()
dataframeEighteen['Date'] = pd.to_datetime(dataframeEighteen['Date'], errors='coerce')
monthlyEighteen['InterestRate']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlyEighteen['CrudeOil']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlyEighteen['PSXEquity']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlyEighteen['USDToPKR']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlyEighteen['KSEPrice']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlyEighteen['GoldRate']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlyEighteen['ArifHabib']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlyEighteen['AskariBank']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlyEighteen['EngroPowergen']=dataframeEighteen.groupby([dataframeEighteen['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlyEighteen['InterestRate'] = monthlyEighteen['InterestRate'].round(decimals=3)
monthlyEighteen['CrudeOil'] = monthlyEighteen['CrudeOil'].round(decimals=3)
monthlyEighteen['PSXEquity'] = monthlyEighteen['PSXEquity'].round(decimals=3)
monthlyEighteen['KSEPrice'] = monthlyEighteen['KSEPrice'].round(decimals=3)
monthlyEighteen['GoldRate'] = monthlyEighteen['GoldRate'].round(decimals=3)
monthlyEighteen['ArifHabib']= monthlyEighteen['ArifHabib'].round(decimals=3)
monthlyEighteen['AskariBank'] = monthlyEighteen['AskariBank'].round(decimals=3)
monthlyEighteen['EngroPowergen'] = monthlyEighteen['EngroPowergen'].round(decimals=3)


dictionaryMonthly2018 = monthlyEighteen.to_dict('records')
dictionaryMonthly2018
# Out:
# [{'InterestRate': 0.023,
#   'CrudeOil': 0.282,
#   'PSXEquity': 0.744,
#   'USDToPKR': 0.06413636363636364,
#   'KSEPrice': 0.634,
#   'GoldRate': 0.238,
#   'ArifHabib': 0.542,
#   'AskariBank': 0.548,
#   'EngroPowergen': 0.828},
#  {'InterestRate': 0.043,
#   'CrudeOil': 0.263,
#   'PSXEquity': 0.806,
#   'USDToPKR': 0.0635263157894737,
#   'KSEPrice': 0.635,
#   'GoldRate': 0.238,
#   'ArifHabib': 0.538,
#   'AskariBank': 0.505,
#   'EngroPowergen': 0.843},
#  {'InterestRate': 0.049,
#   'CrudeOil': 0.266,
#   'PSXEquity': 0.893,
#   'USDToPKR': 0.08114285714285714,
#   'KSEPrice': 0.657,
#   'GoldRate': 0.241,
#   'ArifHabib': 0.473,
#   'AskariBank': 0.598,
#   'EngroPowergen': 0.809},
#  {'InterestRate': 0.047,
#   'CrudeOil': 0.262,
#   'PSXEquity': 0.863,
#   'USDToPKR': 0.11185714285714286,
#   'KSEPrice': 0.728,
#   'GoldRate': 0.26,
#   'ArifHabib': 0.493,
#   'AskariBank': 0.674,
#   'EngroPowergen': 0.844},
#  {'InterestRate': 0.057,
#   'CrudeOil': 0.299,
# ...

# %%
dataframeEighteen.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2018
list5=[]
list5=dataframeEighteen.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list5['index1']=list5.index
print(list5)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil        0.292915       1
# 2    InterestRate       PSXEquity       -0.866032       2
# 3    InterestRate        USDToPKR        0.947460       3
# 4    InterestRate        KSEPrice       -0.783513       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle       -0.017199     220
# 221    GoldGoogle       PSXGoogle        0.332392     221
# 222    GoldGoogle    USDPKRGoogle        0.652997     222
# 223    GoldGoogle       KSEGoogle       -0.133081     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation_2018 = list5.to_dict('index')
dictionary_relation_2018
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': 0.2929146766563998,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.8660316515066039,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.9474596284479806,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.7835128257645417,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': 0.7821076391999674,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': -0.5475593314509243,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': 0.635780386274519,
#   'index1': 7},
#  8: {'Factor1': 'InterestRate',
# ...

# %%
#Working on 2017 Dataset
dataframeSeventeen = database_data.loc[(database_data['Date'] >= '2017-01-01')
                     & (database_data['Date'] <= '2017-12-31')]
dataframeSeventeen['Date'] = dataframeSeventeen['Date'].astype(str)
dataframeSeventeen = dataframeSeventeen.reset_index(drop=True)
dataframeSeventeen.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\2796999181.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeSeventeen['Date'] = dataframeSeventeen['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2017-12-29         0.021     0.265      0.721     0.063     0.516
# 1  2017-12-28         0.021     0.268      0.672     0.063     0.512
# 2  2017-12-27         0.020     0.266      0.625     0.063     0.504
# 3  2017-12-26         0.020     0.263      0.578     0.063     0.479
# 4  2017-12-22         0.020     0.259      0.531     0.063     0.476
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary17 = dataframeSeventeen.to_dict('records')
dictionary17
# Out:
# [{'Date': '2017-12-29',
#   'InterestRate': 0.021,
#   'CrudeOil': 0.265,
#   'PSXEquity': 0.721,
#   'USDToPKR': 0.063,
#   'KSEPrice': 0.516,
#   'GoldRate': 0.224,
#   'ArifHabib': 0.511,
#   'AskariBank': 0.515,
#   'EngroPowergen': 0.792,
#   'InterestGoogle': 57.0,
#   'CrudeOilGoogle': 28.0,
#   'PSXGoogle': 45.0,
#   'USDPKRGoogle': 39.0,
#   'KSEGoogle': 44.0,
#   'GoldGoogle': 45.0},
#  {'Date': '2017-12-28',
#   'InterestRate': 0.021,
#   'CrudeOil': 0.268,
#   'PSXEquity': 0.672,
#   'USDToPKR': 0.063,
#   'KSEPrice': 0.512,
#   'GoldRate': 0.224,
#   'ArifHabib': 0.494,
#   'AskariBank': 0.514,
#   'EngroPowergen': 0.784,
#   'InterestGoogle': 53.0,
#   'CrudeOilGoogle': 0.0,
#   'PSXGoogle': 54.0,
#   'USDPKRGoogle': 40.0,
#   'KSEGoogle': 51.0,
#   'GoldGoogle': 48.0},
#  {'Date': '2017-12-27',
#   'InterestRate': 0.02,
#   'CrudeOil': 0.266,
#   'PSXEquity': 0.625,
#   'USDToPKR': 0.063,
#   'KSEPrice': 0.504,
#   'GoldRate': 0.22,
#   'ArifHabib': 0.497,
# ...

# %%
#Monthly 2017
monthlySeventeen=pd.DataFrame()
dataframeSeventeen['Date'] = pd.to_datetime(dataframeSeventeen['Date'], errors='coerce')
monthlySeventeen['InterestRate']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlySeventeen['CrudeOil']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlySeventeen['PSXEquity']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlySeventeen['USDToPKR']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlySeventeen['KSEPrice']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlySeventeen['GoldRate']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlySeventeen['ArifHabib']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlySeventeen['AskariBank']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlySeventeen['EngroPowergen']=dataframeSeventeen.groupby([dataframeSeventeen['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlySeventeen['InterestRate'] = monthlySeventeen['InterestRate'].round(decimals=3)
monthlySeventeen['CrudeOil'] = monthlySeventeen['CrudeOil'].round(decimals=3)
monthlySeventeen['PSXEquity'] = monthlySeventeen['PSXEquity'].round(decimals=3)
monthlySeventeen['KSEPrice'] = monthlySeventeen['KSEPrice'].round(decimals=3)
monthlySeventeen['GoldRate'] = monthlySeventeen['GoldRate'].round(decimals=3)
monthlySeventeen['ArifHabib']= monthlySeventeen['ArifHabib'].round(decimals=3)
monthlySeventeen['AskariBank'] = monthlySeventeen['AskariBank'].round(decimals=3)
monthlySeventeen['EngroPowergen'] = monthlySeventeen['EngroPowergen'].round(decimals=3)



dictionaryMonthly2017 = monthlySeventeen.to_dict('records')
dictionaryMonthly2017
# Out:
# [{'InterestRate': 0.013,
#   'CrudeOil': 0.314,
#   'PSXEquity': 0.441,
#   'USDToPKR': 0.006761904761904762,
#   'KSEPrice': 0.857,
#   'GoldRate': 0.166,
#   'ArifHabib': 0.806,
#   'AskariBank': 0.911,
#   'EngroPowergen': 0.93},
#  {'InterestRate': 0.013,
#   'CrudeOil': 0.303,
#   'PSXEquity': 0.439,
#   'USDToPKR': 0.0066500000000000005,
#   'KSEPrice': 0.864,
#   'GoldRate': 0.18,
#   'ArifHabib': 0.803,
#   'AskariBank': 0.716,
#   'EngroPowergen': 0.814},
#  {'InterestRate': 0.013,
#   'CrudeOil': 0.277,
#   'PSXEquity': 0.436,
#   'USDToPKR': 0.006590909090909091,
#   'KSEPrice': 0.844,
#   'GoldRate': 0.179,
#   'ArifHabib': 0.741,
#   'AskariBank': 0.515,
#   'EngroPowergen': 0.714},
#  {'InterestRate': 0.017,
#   'CrudeOil': 0.29,
#   'PSXEquity': 0.433,
#   'USDToPKR': 0.0066500000000000005,
#   'KSEPrice': 0.825,
#   'GoldRate': 0.192,
#   'ArifHabib': 0.729,
#   'AskariBank': 0.507,
#   'EngroPowergen': 0.817},
#  {'InterestRate': 0.016,
#   'CrudeOil': 0.271,
# ...

# %%
dataframeSeventeen.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2017
list6=[]
list6=dataframeSeventeen.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list6['index1']=list6.index
print(list6)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil       -0.630184       1
# 2    InterestRate       PSXEquity        0.250512       2
# 3    InterestRate        USDToPKR        0.570360       3
# 4    InterestRate        KSEPrice       -0.652963       4
# ..            ...             ...             ...     ...
# 220    GoldGoogle  CrudeOilGoogle       -0.011520     220
# 221    GoldGoogle       PSXGoogle       -0.222297     221
# 222    GoldGoogle    USDPKRGoogle        0.359636     222
# 223    GoldGoogle       KSEGoogle       -0.055787     223
# 224    GoldGoogle      GoldGoogle        1.000000     224
#
# [225 rows x 4 columns]

# %%
dictionary_relation_2017 = list6.to_dict('index')
dictionary_relation_2017
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': -0.6301838324163777,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': 0.25051196767417494,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.5703596647184956,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.6529631493008058,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': 0.23473929189568257,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': -0.7013840295038796,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': -0.6204425139525364,
#   'index1': 7},
# ...

# %%
#Working on 2016 Dataset
dataframeSixteen = database_data.loc[(database_data['Date'] >= '2016-01-01')
                     & (database_data['Date'] <= '2016-12-31')]
dataframeSixteen['Date'] = dataframeSixteen['Date'].astype(str)
dataframeSixteen = dataframeSixteen.reset_index(drop=True)
dataframeSixteen.head()
# Out:
# C:\Users\faaiz.asif\AppData\Local\Temp\ipykernel_7060\876088097.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframeSixteen['Date'] = dataframeSixteen['Date'].astype(str)
#          Date  InterestRate  CrudeOil  PSXEquity  USDToPKR  KSEPrice  \
# 0  2016-12-30         0.015     0.316      0.442     0.003     0.802
# 1  2016-12-29         0.014     0.315      0.442     0.006     0.797
# 2  2016-12-28         0.014     0.314      0.442     0.007     0.787
# 3  2016-12-27         0.014     0.312      0.442     0.007     0.768
# 4  2016-12-26         0.014     0.281      0.442     0.007     0.759
#
#    GoldRate  ArifHabib  AskariBank  EngroPowergen  InterestGoogle  \
# ...

# %%
#Transforming dataframe into Dictionary
dictionary16 = dataframeSixteen.to_dict('records')
dictionary16
# Out:
# [{'Date': '2016-12-30',
#   'InterestRate': 0.015,
#   'CrudeOil': 0.316,
#   'PSXEquity': 0.442,
#   'USDToPKR': 0.003,
#   'KSEPrice': 0.802,
#   'GoldRate': 0.149,
#   'ArifHabib': 0.77,
#   'AskariBank': 0.875,
#   'EngroPowergen': 0.928,
#   'InterestGoogle': 37.0,
#   'CrudeOilGoogle': 17.0,
#   'PSXGoogle': 0.0,
#   'USDPKRGoogle': 66.0,
#   'KSEGoogle': 25.0,
#   'GoldGoogle': 76.0},
#  {'Date': '2016-12-29',
#   'InterestRate': 0.014,
#   'CrudeOil': 0.315,
#   'PSXEquity': 0.442,
#   'USDToPKR': 0.006,
#   'KSEPrice': 0.797,
#   'GoldRate': 0.151,
#   'ArifHabib': 0.738,
#   'AskariBank': 0.883,
#   'EngroPowergen': 0.937,
#   'InterestGoogle': 36.0,
#   'CrudeOilGoogle': 43.0,
#   'PSXGoogle': 0.0,
#   'USDPKRGoogle': 64.0,
#   'KSEGoogle': 37.0,
#   'GoldGoogle': 92.0},
#  {'Date': '2016-12-28',
#   'InterestRate': 0.014,
#   'CrudeOil': 0.314,
#   'PSXEquity': 0.442,
#   'USDToPKR': 0.007,
#   'KSEPrice': 0.787,
#   'GoldRate': 0.147,
#   'ArifHabib': 0.71,
# ...

# %%
#Monthly 2016
monthlySixteen=pd.DataFrame()
dataframeSixteen['Date'] = pd.to_datetime(dataframeSixteen['Date'], errors='coerce')
monthlySixteen['InterestRate']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'InterestRate': ['mean']})
monthlySixteen['CrudeOil']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'CrudeOil': ['mean']})
monthlySixteen['PSXEquity']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'PSXEquity': ['mean']})
monthlySixteen['USDToPKR']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'USDToPKR': ['mean']})
monthlySixteen['KSEPrice']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'KSEPrice': ['mean']})
monthlySixteen['GoldRate']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'GoldRate': ['mean']})
monthlySixteen['ArifHabib']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'ArifHabib': ['mean']})
monthlySixteen['AskariBank']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'AskariBank': ['mean']})
monthlySixteen['EngroPowergen']=dataframeSixteen.groupby([dataframeSixteen['Date'].dt.month]).agg({'EngroPowergen': ['mean']})

monthlySixteen['InterestRate'] = monthlySixteen['InterestRate'].round(decimals=3)
monthlySixteen['CrudeOil'] = monthlySixteen['CrudeOil'].round(decimals=3)
monthlySixteen['PSXEquity'] = monthlySixteen['PSXEquity'].round(decimals=3)
monthlySixteen['KSEPrice'] = monthlySixteen['KSEPrice'].round(decimals=3)
monthlySixteen['GoldRate'] = monthlySixteen['GoldRate'].round(decimals=3)
monthlySixteen['ArifHabib']= monthlySixteen['ArifHabib'].round(decimals=3)
monthlySixteen['AskariBank'] = monthlySixteen['AskariBank'].round(decimals=3)
monthlySixteen['EngroPowergen'] = monthlySixteen['EngroPowergen'].round(decimals=3)

dictionaryMonthly2016 = monthlySixteen.to_dict('records')
dictionaryMonthly2016
# Out:
# [{'InterestRate': 0.045,
#   'CrudeOil': 0.08,
#   'PSXEquity': 0.429,
#   'USDToPKR': 0.02190909090909091,
#   'KSEPrice': 0.207,
#   'GoldRate': 0.163,
#   'ArifHabib': 0.791,
#   'AskariBank': 0.575,
#   'EngroPowergen': 0.774},
#  {'InterestRate': 0.041,
#   'CrudeOil': 0.046,
#   'PSXEquity': 0.428,
#   'USDToPKR': 0.0058000000000000005,
#   'KSEPrice': 0.17,
#   'GoldRate': 0.17,
#   'ArifHabib': 0.791,
#   'AskariBank': 0.479,
#   'EngroPowergen': 0.677},
#  {'InterestRate': 0.04,
#   'CrudeOil': 0.13,
#   'PSXEquity': 0.428,
#   'USDToPKR': 0.0059545454545454546,
#   'KSEPrice': 0.214,
#   'GoldRate': 0.184,
#   'ArifHabib': 0.742,
#   'AskariBank': 0.39,
#   'EngroPowergen': 0.655},
#  {'InterestRate': 0.04,
#   'CrudeOil': 0.156,
#   'PSXEquity': 0.425,
#   'USDToPKR': 0.006142857142857143,
#   'KSEPrice': 0.258,
#   'GoldRate': 0.183,
#   'ArifHabib': 0.671,
#   'AskariBank': 0.361,
#   'EngroPowergen': 0.654},
#  {'InterestRate': 0.033,
#   'CrudeOil': 0.216,
# ...

# %%
dataframeSixteen.drop('Date', inplace=True, axis=1)

# %%
#Correlation Matrix of 2016
list7=[]
list7=dataframeSixteen.corr().stack().rename_axis(('Factor1', 'Factor2')).reset_index(name='Relation_Value')
list7['index1']=list7.index
print(list7)
# Out:
#           Factor1         Factor2  Relation_Value  index1
# 0    InterestRate    InterestRate        1.000000       0
# 1    InterestRate        CrudeOil       -0.620031       1
# 2    InterestRate       PSXEquity       -0.666033       2
# 3    InterestRate        USDToPKR        0.129043       3
# 4    InterestRate        KSEPrice       -0.782382       4
# ..            ...             ...             ...     ...
# 191    GoldGoogle  InterestGoogle       -0.054097     191
# 192    GoldGoogle  CrudeOilGoogle       -0.061272     192
# 193    GoldGoogle    USDPKRGoogle        0.388880     193
# 194    GoldGoogle       KSEGoogle        0.051028     194
# 195    GoldGoogle      GoldGoogle        1.000000     195
#
# [196 rows x 4 columns]

# %%
dictionary_relation_2016 = list7.to_dict('index')
dictionary_relation_2016
# Out:
# {0: {'Factor1': 'InterestRate',
#   'Factor2': 'InterestRate',
#   'Relation_Value': 1.0,
#   'index1': 0},
#  1: {'Factor1': 'InterestRate',
#   'Factor2': 'CrudeOil',
#   'Relation_Value': -0.620031111031938,
#   'index1': 1},
#  2: {'Factor1': 'InterestRate',
#   'Factor2': 'PSXEquity',
#   'Relation_Value': -0.6660330291602721,
#   'index1': 2},
#  3: {'Factor1': 'InterestRate',
#   'Factor2': 'USDToPKR',
#   'Relation_Value': 0.12904281855757224,
#   'index1': 3},
#  4: {'Factor1': 'InterestRate',
#   'Factor2': 'KSEPrice',
#   'Relation_Value': -0.7823824795732066,
#   'index1': 4},
#  5: {'Factor1': 'InterestRate',
#   'Factor2': 'GoldRate',
#   'Relation_Value': -0.2296002294204884,
#   'index1': 5},
#  6: {'Factor1': 'InterestRate',
#   'Factor2': 'ArifHabib',
#   'Relation_Value': 0.2265844503940314,
#   'index1': 6},
#  7: {'Factor1': 'InterestRate',
#   'Factor2': 'AskariBank',
#   'Relation_Value': -0.2955500541485885,
#   'index1': 7},
#  8: {'Factor1': 'InterestRate',
# ...

# %%
app=Flask(__name__)  
CORS(app, support_credentials=True)

# %%
@app.route('/')
def index():
    return "Calling the API"

# %%
@app.route('/prices', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPrice():
    return jsonify(dictionary)
@app.route('/prices/2016', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceSixteen():
    return jsonify(dictionary16)
@app.route('/prices/2017', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceSeventeen():
    return jsonify(dictionary17)
@app.route('/prices/2018', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceEighteen():
    return jsonify(dictionary18)
@app.route('/prices/2019', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceNineteen():
    return jsonify(dictionary19)
@app.route('/prices/2020', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceTwenty():
    return jsonify(dictionary20)
@app.route('/prices/2021', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceTwentyOne():
    return jsonify(dictionary21)
@app.route('/prices/2022', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceTwentyTwo():
    return jsonify(dictionary22)
@app.route('/prices/yearlyagg', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceYearlyagg():
    return jsonify(dictionaryYearlyagg)
@app.route('/matrix', methods=['GET'])
@cross_origin(supports_credentials=True)
def getAllMatrix():
    return jsonify(dictionary_relation)
@app.route('/matrix/2022', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixTwentyTwo():
    return jsonify(dictionary_relation_2022)
@app.route('/matrix/2021', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixTwentyOne():
    return jsonify(dictionary_relation_2021)
@app.route('/matrix/2020', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixTwenty():
    return jsonify(dictionary_relation_2020)
@app.route('/matrix/2019', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixNineteen():
    return jsonify(dictionary_relation_2019)
@app.route('/matrix/2018', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixEighteen():
    return jsonify(dictionary_relation_2018)
@app.route('/matrix/2017', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixSeventeen():
    return jsonify(dictionary_relation_2017)
@app.route('/matrix/2016', methods=['GET'])
@cross_origin(supports_credentials=True)
def getMatrixSixteen():
    return jsonify(dictionary_relation_2016)
@app.route('/prices/monthly2016', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceSixteenMonthly():
    return jsonify(dictionaryMonthly2016)
@app.route('/prices/monthly2017', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceSeventeenMonthly():
    return jsonify(dictionaryMonthly2017)
@app.route('/prices/monthly2018', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceEighteenMonthly():
    return jsonify(dictionaryMonthly2018)
@app.route('/prices/monthly2019', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceNineteenMonthly():
    return jsonify(dictionaryMonthly2019)
@app.route('/prices/monthly2020', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPricesTwentyMonthly():
    return jsonify(dictionaryMonthly2020)
@app.route('/prices/monthly2021', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceTwentyOneMonthly():
    return jsonify(dictionaryMonthly2021)
@app.route('/prices/monthly2022', methods=['GET'])
@cross_origin(supports_credentials=True)
def getPriceTwentyTwoMonthly():
    return jsonify(dictionaryMonthly2022)

# %%
if __name__=="__main__":
    from werkzeug.serving import run_simple
    run_simple('localhost', 9000, app)
# Out:
#  * Running on http://localhost:9000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Aug/2022 14:43:54] "GET /matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:43:54] "GET /matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:43:59] "GET /prices/yearlyagg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:43:59] "GET /prices/2022 HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:43:59] "GET /prices/monthly2022 HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:43:59] "GET /prices/yearlyagg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:44:00] "GET /prices/2022 HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:44:00] "GET /prices/monthly2022 HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:44:00] "GET /prices/yearlyagg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:44:00] "GET /prices/yearlyagg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:44:04] "GET /prices/monthly2016 HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Aug/2022 14:44:09] "GET /prices/monthly2017 HTTP/1.1" 200 -
# ...
